# %% [markdown]
# # Week 06
# ### Author : Bemnet Girma
# ### Roll No. 2164006
# ### KiiT University, Bhubanewar
# ### Program : MTech in Data Analytics
# ### Subject : Business Analytics Intelligence
# ### Lab Assignment Week Six

# %%
#for array
import numpy as np
#for dataset
import pandas as pd
#for visualization
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#overview of each columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
#dimension of dataset
df.shape
# Out:
# (150, 5)

# %%
#overview of number of non-nan records in a column
df.count()
# Out:
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# target               150
# dtype: int64

# %% [markdown]
# # View basic statistics of Iris dataset

# %%
#numerical data statistical summary
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# # Get observations of each species from iris dataset

# %%
#categorical data group summary of a column
df["target"].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64

# %%
# percentage distribution of each unique data in a column
df.target.value_counts(normalize=True)
# Out:
# 0    0.333333
# 1    0.333333
# 2    0.333333
# Name: target, dtype: float64

# %%
# visualize distribution of each unique data in a column using bar chart
df.target.value_counts().plot(kind="barh")
plt.show()

# %%
# visualize % distribution of each unique data in a column using pie chart
df.target.value_counts(normalize=True).plot(kind="pie", figsize=(6,6))
plt.show()

# %% [markdown]
# # Create a plot to get general statistics of iris dataset

# %%
# visualize numerical data attributes using histograms
df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# # Create a graph to find relationship between sepal length and width of iris dataset

# %%
#correlation matrix
corr_matrix = df.corr()

# %%
corr_matrix["target"].sort_values(ascending=False)
# Out:
# target               1.000000
# petal width (cm)     0.956547
# petal length (cm)    0.949035
# sepal length (cm)    0.782561
# sepal width (cm)    -0.426658
# Name: target, dtype: float64

# %%
import seaborn as sn
corr = df.corr()
#mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(9, 7))
cmap = sn.diverging_palette(230, 20, as_cmap=True)

#visualization of correlation matrix
sn.heatmap(corr, cmap=cmap, vmax=0.3, center=0, annot=True,
          square=True, linewidths=0.5, cbar_kws={"shrink": 0.5})
# Out:
# <AxesSubplot:>

# %%
# visualize more correlated attributes using scatter plot (here more than 0.1)
from pandas.plotting import scatter_matrix
attributes = ["sepal length (cm)",
              "sepal width (cm)",
              "petal length (cm)",
              "petal width (cm)",
              "target"]
scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='sepal width (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='petal length (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='petal width (cm)', ylabel='sepal length (cm)'>,
#         <AxesSubplot:xlabel='target', ylabel='sepal length (cm)'>],
#        [<AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='sepal width (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='petal length (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='petal width (cm)', ylabel='sepal width (cm)'>,
#         <AxesSubplot:xlabel='target', ylabel='sepal width (cm)'>],
#        [<AxesSubplot:xlabel='sepal length (cm)', ylabel='petal length (cm)'>,
#         <AxesSubplot:xlabel='sepal width (cm)', ylabel='petal length (cm)'>,
# ...

# %%
#correlation matrix
corr_matrix_1 = df.corr()

# %%
#correlation between sepal width and sepal length
corr_matrix_1["sepal width (cm)"][0]
# Out:
# -0.11756978413300088

# %%
#visualization of correlation between dependent and independent variables
from pandas.plotting import scatter_matrix
df.plot(kind="scatter", x="sepal length (cm)", y="sepal width (cm)", alpha=1)
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
df0 = df[df.target == 0]
df1 = df[df.target == 1]
df2 = df[df.target == 2]

# %%
#visualize with scatter plot
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(df0["sepal length (cm)"], df0["sepal width (cm)"], color="green", marker='+')
plt.scatter(df1["sepal length (cm)"], df1["sepal width (cm)"], color="red", marker='^')
plt.scatter(df2["sepal length (cm)"], df2["sepal width (cm)"], color="blue", marker='*')

# %% [markdown]
# # Using sklearn split dataset 70% train and 30% test data (train = 105, test = 45) and predict the response for test dataset (sepal length and sepal width) using knn (k=5)

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['target'], axis = 'columns')
y = df.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
len(X_train)
# Out:
# 105

# %%
len(X_test)
# Out:
# 45

# %%
#train using KNN model
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 5)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 0, 2, 1, 1, 0, 1, 1, 0, 0, 1, 1,
#        1, 0, 2, 1, 0, 0, 1, 2, 1, 2, 1, 2, 2, 0, 1, 0, 1, 2, 2, 0, 1, 2,
#        1])

# %%
model.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[14,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  1, 12]], dtype=int64)

# %%
#visualize confusion matrix
# %matplotlib inline
import seaborn as sn
plt.figure(figsize = (7, 5))
sn.heatmap(cm, annot = True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(42.0, 0.5, 'Truth')
